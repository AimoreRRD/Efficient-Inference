# %% [markdown]
# # Load Data

# %%
import pandas as pd

data_path = 'data/data.csv'
all_data = pd.read_csv(data_path, sep=',')
pd.set_option('max_rows', 30)

# %%
class_dict = {1:'Company',
              2:'EducationalInstitution',
              3:'Artist',
              4:'Athlete',
              5:'OfficeHolder',
              6:'MeanOfTransportation',
              7:'Building',
              8:'NaturalPlace',
              9:'Village',
              10:'Animal',
              11:'Plant',
              12:'Album',
              13:'Film',
              14:'WrittenWork'}

# %%
all_data['Class_name'] = all_data['Class'].map(class_dict)
all_data
# Out:
#         Class                                     Name   Class_name
# 0           1                         E. D. Abbott Ltd      Company
# 1           1                           Schwan-Stabilo      Company
# 2           1                               Q-workshop      Company
# 3           1        Marvell Software Solutions Israel      Company
# 4           1              Bergan Mercy Medical Center      Company
# 5           1                       The Unsigned Guide      Company
# 6           1                        Rest of the world      Company
# 7           1                               Globoforce      Company
# 8           1                                Rompetrol      Company
# 9           1                          Wave Accounting      Company
# 10          1                       Angstrem (company)      Company
# 11          1                          I-innovate (UK)      Company
# 12          1                                      JVC      Company
# 13          1                                 Toei Bus      Company
# 14          1                        Tear Drop Records      Company
# ...       ...                                      ...          ...
# 548772     14                             HaOlam HaZeh  WrittenWork
# 548773     14                         The OMAC Project  WrittenWork
# 548774     14                        Fledgling (novel)  WrittenWork
# 548775     14                      Death of a Salesman  WrittenWork
# 548776     14            The Wild Geese (Carney novel)  WrittenWork
# 548777     14                           Fluide Glacial  WrittenWork
# 548778     14                           Poison in Jest  WrittenWork
# 548779     14                      Out of This Furnace  WrittenWork
# 548780     14                             Bush's Brain  WrittenWork
# 548781     14                          Risk (magazine)  WrittenWork
# 548782     14           The Worst Band in the Universe  WrittenWork
# 548783     14                    Poor Arnold's Almanac  WrittenWork
# 548784     14  The Girls' Guide to Hunting and Fishing  WrittenWork
# 548785     14       Wash This Blood Clean from My Hand  WrittenWork
# 548786     14       Virginia Environmental Law Journal  WrittenWork
#
# [548787 rows x 3 columns]

# %% [markdown]
# # Remove Annotations (anything between parenthesis)

# %%
import re
all_data['Name'] = [re.sub(r'\([^)]*\)', '', x) for x in all_data['Name']]
all_data
# Out:
#         Class                                     Name   Class_name
# 0           1                         E. D. Abbott Ltd      Company
# 1           1                           Schwan-Stabilo      Company
# 2           1                               Q-workshop      Company
# 3           1        Marvell Software Solutions Israel      Company
# 4           1              Bergan Mercy Medical Center      Company
# 5           1                       The Unsigned Guide      Company
# 6           1                        Rest of the world      Company
# 7           1                               Globoforce      Company
# 8           1                                Rompetrol      Company
# 9           1                          Wave Accounting      Company
# 10          1                                Angstrem       Company
# 11          1                              I-innovate       Company
# 12          1                                      JVC      Company
# 13          1                                 Toei Bus      Company
# 14          1                        Tear Drop Records      Company
# ...       ...                                      ...          ...
# 548772     14                             HaOlam HaZeh  WrittenWork
# 548773     14                         The OMAC Project  WrittenWork
# 548774     14                               Fledgling   WrittenWork
# 548775     14                      Death of a Salesman  WrittenWork
# 548776     14                          The Wild Geese   WrittenWork
# 548777     14                           Fluide Glacial  WrittenWork
# 548778     14                           Poison in Jest  WrittenWork
# 548779     14                      Out of This Furnace  WrittenWork
# 548780     14                             Bush's Brain  WrittenWork
# 548781     14                                    Risk   WrittenWork
# 548782     14           The Worst Band in the Universe  WrittenWork
# 548783     14                    Poor Arnold's Almanac  WrittenWork
# 548784     14  The Girls' Guide to Hunting and Fishing  WrittenWork
# 548785     14       Wash This Blood Clean from My Hand  WrittenWork
# 548786     14       Virginia Environmental Law Journal  WrittenWork
#
# [548787 rows x 3 columns]

# %% [markdown]
# # Load USE

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import tf_sentencepiece

tf.logging.set_verbosity(tf.logging.ERROR)
module_url = 'module_Multi_Large/'

g = tf.Graph()
with g.as_default():
    similarity_input_placeholder = tf.placeholder(tf.string, shape=(None))
    embed = hub.Module(module_url)
    encoding_tensor = embed(similarity_input_placeholder)
    init_op = tf.group([tf.global_variables_initializer(), tf.tables_initializer()])
g.finalize()

sess = tf.Session(graph=g)
sess.run(init_op)

# %% [markdown]
# # Encode

# %%
from tqdm import tqdm

def embed_df(df, col):
    message_embedding = []
    size_batch = 200
    data_size = len(df[col])
    num_batches = int(data_size/size_batch)+1
    for x in tqdm(range(num_batches)):
        samples = list(df[col][(x*size_batch):((x+1)*size_batch)])
        if type(samples) is pd.core.series.Series:
            message_embedding.extend(sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: [samples]}))
        else:
            message_embedding.extend(sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: samples}))

    df[col+'_emb'] = message_embedding
    
    return df

# %%
import pickle

load = True
file_path = 'complete_data.pkl'

if load == True:
    with open(file_path, 'rb') as fl:
        all_data = pickle.load(fl)
else:
    columns = ['Name']
    for col in columns:
        all_data = embed_df(all_data, col)
    
    with open(file_path, 'wb') as fs:
        pickle.dump(all_data , fs)

# %% [markdown]
# # Check Data Distribution

# %%
all_data['Class'].value_counts().sort_values(ascending=False)
# Out:
# 1     40000
# 2     40000
# 3     40000
# 4     40000
# 5     40000
# 6     40000
# 7     40000
# 8     40000
# 9     40000
# 10    40000
# 11    40000
# 12    40000
# 13    40000
# 14    28787
# Name: Class, dtype: int64

# %% [markdown]
# # Split into Train, Validate and Test (Stratified)

# %%
from torch.utils.data import Dataset
import torch
import torch.utils.data as data

class my_dataset(Dataset):
    def __init__(self, data):
        input_ = [torch.tensor(x).float() for x in data['Name_emb'].values]
        label_ = [torch.tensor(x).long() for x in data['Class'].values]
        self.samples = list(zip(input_, label_))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# %%
from sklearn.model_selection import train_test_split

X = all_data.drop('Class', axis=1)
y = all_data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, stratify=y_test, test_size=0.5)

train = pd.concat([X_train, y_train.reindex(X_train.index)], axis=1)
validate = pd.concat([X_val, y_val.reindex(X_val.index)], axis=1)
test = pd.concat([X_test, y_test.reindex(X_test.index)], axis=1)

trainset = my_dataset(train)
validateset = my_dataset(validate)
testset = my_dataset(test)
print('Dataset Length: \n -train (90%%):\t\t %d \n -validate (10%%):\t %d \n -test (10%%):\t\t %d' % (len(trainset), len(validateset), len(testset)))
# Out:
# Dataset Length:
#  -train (90%):		 439029
#  -validate (10%):	 54879
#  -test (10%):		 54879

# %%
batch_size = 10000

trainloader = data.DataLoader(trainset, batch_size=batch_size, num_workers=0, shuffle=True)
validateloader = data.DataLoader(validateset, batch_size=batch_size, num_workers=0, shuffle=True)
testloader = data.DataLoader(testset, batch_size=batch_size, num_workers=0, shuffle=True)

# %% [markdown]
# # Define Network

# %%
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Net(nn.Module):
    def __init__(self, EMBED_DIM, CLASS_DIM):
        super(Net, self).__init__()
        self.number_neurons = 1000
        self.fc1 = nn.Sequential(nn.Linear(EMBED_DIM, self.number_neurons),
                                 nn.BatchNorm1d(self.number_neurons))
        self.fc2 = nn.Sequential(nn.Linear(self.number_neurons, self.number_neurons),
                                 nn.BatchNorm1d(self.number_neurons),
                                 nn.Dropout(0.3, inplace=True))
        self.fc3 = nn.Sequential(nn.Linear(self.number_neurons, self.number_neurons),
                                 nn.BatchNorm1d(self.number_neurons),
                                 nn.Dropout(0.3, inplace=True))
        self.fc4 = nn.Sequential(nn.Linear(self.number_neurons, self.number_neurons),
                                 nn.BatchNorm1d(self.number_neurons),
                                 nn.Dropout(0.3, inplace=True))
        self.fc5 = nn.Sequential(nn.Linear(self.number_neurons, CLASS_DIM))
        
    def forward(self, x):
        x = F.leaky_relu(self.fc1(x))
        x = F.leaky_relu(self.fc2(x))
        x = F.leaky_relu(self.fc3(x))
        x = F.leaky_relu(self.fc4(x))
        x = F.softmax(self.fc5(x), dim=1)
        return (x)
    
EMBED_DIM, CLASS_DIM = trainloader.dataset[0][0].shape[0], len(class_dict)+1

net = Net(EMBED_DIM, CLASS_DIM)
net.to(device)
# Out:
# Net(
#   (fc1): Sequential(
#     (0): Linear(in_features=512, out_features=1000, bias=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=1000, out_features=1000, bias=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout(p=0.3, inplace=True)
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=1000, out_features=1000, bias=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout(p=0.3, inplace=True)
#   )
#   (fc4): Sequential(
#     (0): Linear(in_features=1000, out_features=1000, bias=True)
#     (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout(p=0.3, inplace=True)
#   )
#   (fc5): Sequential(
#     (0): Linear(in_features=1000, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# # Define Evaluate Function

# %%
def evaluate(net, data_loader):

    loss = []
    accuracy = []

    y_true = []
    y_pred = []
    
    for input_labels in data_loader:
        inputs, labels = input_labels[0].to(device), input_labels[1].to(device)

        outputs = net(inputs)

        loss.append(criterion(outputs, labels).data.cpu().numpy())
        outputs = outputs.to('cpu').detach().numpy() 
        labels = labels.to('cpu').detach().numpy() 

        predict = [np.argmax(x) for x in outputs]
        labels = np.array([int(x) for x in labels])

        accuracy.append(list(predict==labels).count(True)/len(predict))

        y_true.extend(labels)
        y_pred.extend(predict)
        

    print('Acc: %.2f'% np.mean(accuracy))
    print('Loss: %.2f'% np.mean(loss))
    return y_true, y_pred

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.5, momentum=0.5)

# %%
display_n_loss = 3
display_n_loss = int(len(trainset)/(display_n_loss * batch_size))

EPOCHS = 100
display_n_epoch = 10

for epoch in range(EPOCHS):  # loop over the dataset multiple times

    running_loss = 0.0
    net.train()
    print('--------------- Epoch', epoch)
    for i, input_labels in enumerate(trainloader, 0):
        inputs, labels = input_labels[0].to(device), input_labels[1].to(device)
    
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        
        if i % display_n_loss == display_n_loss-1:    # print every N mini-batches
            print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, running_loss
# [96,    14] loss: 2.149
# [96,    28] loss: 2.149
# [96,    42] loss: 2.148
# --------------- Epoch 96
# [97,    14] loss: 2.148
# [97,    28] loss: 2.150
# [97,    42] loss: 2.150
# --------------- Epoch 97
# [98,    14] loss: 2.146
# [98,    28] loss: 2.149
# [98,    42] loss: 2.150
# --------------- Epoch 98
# [99,    14] loss: 2.146
# [99,    28] loss: 2.149
# [99,    42] loss: 2.150
# --------------- Epoch 99
# [100,    14] loss: 2.147
# [100,    28] loss: 2.150
# [100,    42] loss: 2.147
# -> Evaluate
# 	Train:
# Acc: 0.67
# Loss: 2.14
# 	Validate:
# Acc: 0.59
# Loss: 2.22
# 	Test:
# Acc: 0.60
# Loss: 2.22
# Finished Training

# %%
print('-> Evaluate') 
net.eval()
print('\tTrain:')
evaluate(net, trainloader)
print('\tValidate:')
evaluate(net, validateloader)
print('\tTest:')
evaluate(net, testloader)
print()
# Out:
# -> Evaluate
# 	Train:
# Acc: 0.08
# Loss: 2.71
# 	Validate:
# Acc: 0.08
# Loss: 2.71
# 	Test:
# Acc: 0.08
# Loss: 2.71

# %% [markdown]
# # Statistics on Test data

# %%
from pandas_ml import ConfusionMatrix

y_true, y_pred = evaluate(testloader)
cm = ConfusionMatrix(y_true, y_pred)
# Out:
# Acc: 0.65
# Loss: 2.16

# %%
pd.set_option('precision', 3)

cm_df_report = cm.classification_report
classes_name = list(class_dict.values())
classes_name.append('Avg_Total')

cm_df_report.index = classes_name
cm_df_report
# Out:
#                        precision recall F1_score support
# Company                    0.661  0.731    0.694    4000
# EducationalInstitution     0.949  0.957    0.953    4000
# Artist                     0.392  0.256     0.31    4000
# Athlete                    0.404  0.702    0.513    4000
# OfficeHolder               0.597   0.35    0.441    4000
# MeanOfTransportation       0.907  0.868    0.887    4000
# Building                   0.879  0.823     0.85    4000
# NaturalPlace               0.811  0.805    0.808    4000
# Village                    0.711  0.804    0.755    4000
# Animal                     0.653  0.705    0.678    4000
# Plant                      0.742  0.698    0.719    4000
# Album                      0.534  0.593    0.562    4000
# Film                       0.447  0.529    0.484    4000
# WrittenWork                0.641  0.268    0.378    2879
# Avg_Total                  0.667  0.657    0.651   54879

# %%
cm_od = cm.stats()
cm_od['class'].columns = class_dict.values()
cm_od['class']
# Out:
# /home/hal9002/.local/lib/python3.5/site-packages/pandas_ml/confusion_matrix/stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
#                                       Company EducationalInstitution  Artist  \
# Population                              54879                  54879   54879
# P: Condition positive                    4000                   4000    4000
# N: Condition negative                   50879                  50879   50879
# Test outcome positive                    4422                   4033    2613
# Test outcome negative                   50457                  50846   52266
# TP: True Positive                        2922                   3829    1025
# TN: True Negative                       49379                  50675   49291
# FP: False Positive                       1500                    204    1588
# FN: False Negative                       1078                    171    2975
# TPR: (Sensitivity, hit rate, recall)    0.731                  0.957   0.256
# TNR=SPC: (Specificity)                  0.971                  0.996   0.969
# PPV: Pos Pred Value (Precision)         0.661                  0.949   0.392
# NPV: Neg Pred Value                     0.979                  0.997   0.943
# FPR: False-out                         0.0295                0.00401  0.0312
# FDR: False Discovery Rate               0.339                 0.0506   0.608
# FNR: Miss Rate                           0.27                 0.0428   0.744
# ACC: Accuracy                           0.953                  0.993   0.917
# F1 score                                0.694                  0.953    0.31
# MCC: Matthews correlation coefficient    0.67                   0.95   0.275
# Informedness                            0.701                  0.953   0.225
# Markedness                              0.639                  0.946   0.335
# Prevalence                             0.0729                 0.0729  0.0729
# LR+: Positive likelihood ratio           24.8                    239    8.21
# LR-: Negative likelihood ratio          0.278                 0.0429   0.768
# DOR: Diagnostic odds ratio               89.2               5.56e+03    10.7
# FOR: False omission rate               0.0214                0.00336  0.0569
#
#                                       Athlete OfficeHolder  \
# Population                              54879        54879
# P: Condition positive                    4000         4000
# N: Condition negative                   50879        50879
# Test outcome positive                    6944         2344
# Test outcome negative                   47935        52535
# TP: True Positive                        2807         1399
# TN: True Negative                       46742        49934
# FP: False Positive                       4137          945
# FN: False Negative                       1193         2601
# TPR: (Sensitivity, hit rate, recall)    0.702         0.35
# TNR=SPC: (Specificity)                  0.919        0.981
# PPV: Pos Pred Value (Precision)         0.404        0.597
# NPV: Neg Pred Value                     0.975         0.95
# FPR: False-out                         0.0813       0.0186
# FDR: False Discovery Rate               0.596        0.403
# FNR: Miss Rate                          0.298         0.65
# ACC: Accuracy                           0.903        0.935
# F1 score                                0.513        0.441
# MCC: Matthews correlation coefficient   0.485        0.426
# Informedness                             0.62        0.331
# Markedness                              0.379        0.547
# Prevalence                             0.0729       0.0729
# LR+: Positive likelihood ratio           8.63         18.8
# LR-: Negative likelihood ratio          0.325        0.663
# DOR: Diagnostic odds ratio               26.6         28.4
# FOR: False omission rate               0.0249       0.0495
#
#                                       MeanOfTransportation Building  \
# Population                                           54879    54879
# P: Condition positive                                 4000     4000
# N: Condition negative                                50879    50879
# Test outcome positive                                 3824     3744
# Test outcome negative                                51055    51135
# TP: True Positive                                     3470     3291
# TN: True Negative                                    50525    50426
# FP: False Positive                                     354      453
# FN: False Negative                                     530      709
# TPR: (Sensitivity, hit rate, recall)                 0.868    0.823
# TNR=SPC: (Specificity)                               0.993    0.991
# PPV: Pos Pred Value (Precision)                      0.907    0.879
# NPV: Neg Pred Value                                   0.99    0.986
# FPR: False-out                                     0.00696   0.0089
# FDR: False Discovery Rate                           0.0926    0.121
# FNR: Miss Rate                                       0.133    0.177
# ACC: Accuracy                                        0.984    0.979
# F1 score                                             0.887     0.85
# MCC: Matthews correlation coefficient                0.879    0.839
# Informedness                                         0.861    0.814
# Markedness                                           0.897    0.865
# Prevalence                                          0.0729   0.0729
# LR+: Positive likelihood ratio                         125     92.4
# LR-: Negative likelihood ratio                       0.133    0.179
# DOR: Diagnostic odds ratio                             934      517
# FOR: False omission rate                            0.0104   0.0139
#
#                                       NaturalPlace Village  Animal   Plant  \
# Population                                   54879   54879   54879   54879
# P: Condition positive                         4000    4000    4000    4000
# N: Condition negative                        50879   50879   50879   50879
# Test outcome positive                         3968    4528    4313    3762
# Test outcome negative                        50911   50351   50566   51117
# TP: True Positive                             3220    3218    2818    2791
# TN: True Negative                            50131   49569   49384   49908
# FP: False Positive                             748    1310    1495     971
# FN: False Negative                             780     782    1182    1209
# TPR: (Sensitivity, hit rate, recall)         0.805   0.804   0.705   0.698
# TNR=SPC: (Specificity)                       0.985   0.974   0.971   0.981
# PPV: Pos Pred Value (Precision)              0.811   0.711   0.653   0.742
# NPV: Neg Pred Value                          0.985   0.984   0.977   0.976
# FPR: False-out                              0.0147  0.0257  0.0294  0.0191
# FDR: False Discovery Rate                    0.189   0.289   0.347   0.258
# FNR: Miss Rate                               0.195   0.196   0.295   0.302
# ACC: Accuracy                                0.972   0.962   0.951    0.96
# F1 score                                     0.808   0.755   0.678   0.719
# MCC: Matthews correlation coefficient        0.793   0.736   0.652   0.698
# Informedness                                  0.79   0.779   0.675   0.679
# Markedness                                   0.796   0.695    0.63   0.718
# Prevalence                                  0.0729  0.0729  0.0729  0.0729
# LR+: Positive likelihood ratio                54.8    31.2      24    36.6
# LR-: Negative likelihood ratio               0.198   0.201   0.304   0.308
# DOR: Diagnostic odds ratio                     277     156    78.8     119
# FOR: False omission rate                    0.0153  0.0155  0.0234  0.0237
#
#                                         Album    Film WrittenWork
# Population                              54879   54879       54879
# P: Condition positive                    4000    4000        2879
# N: Condition negative                   50879   50879       52000
# Test outcome positive                    4445    4736        1203
# Test outcome negative                   50434   50143       53676
# TP: True Positive                        2372    2115         771
# TN: True Negative                       48806   48258       51568
# FP: False Positive                       2073    2621         432
# FN: False Negative                       1628    1885        2108
# TPR: (Sensitivity, hit rate, recall)    0.593   0.529       0.268
# TNR=SPC: (Specificity)                  0.959   0.948       0.992
# PPV: Pos Pred Value (Precision)         0.534   0.447       0.641
# NPV: Neg Pred Value                     0.968   0.962       0.961
# FPR: False-out                         0.0407  0.0515     0.00831
# FDR: False Discovery Rate               0.466   0.553       0.359
# FNR: Miss Rate                          0.407   0.471       0.732
# ACC: Accuracy                           0.933   0.918       0.954
# F1 score                                0.562   0.484       0.378
# MCC: Matthews correlation coefficient   0.526   0.442       0.395
# Informedness                            0.552   0.477       0.259
# Markedness                              0.501   0.409       0.602
# Prevalence                             0.0729  0.0729      0.0525
# LR+: Positive likelihood ratio           14.6    10.3        32.2
# LR-: Negative likelihood ratio          0.424   0.497       0.738
# DOR: Diagnostic odds ratio               34.3    20.7        43.7
# FOR: False omission rate               0.0323  0.0376      0.0393

# %%
cm_df = cm.to_dataframe()
cm_df.columns = class_dict.values()
cm_df.index = class_dict.values()

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap

my_cmap = ListedColormap(sns.color_palette("BuGn", 14).as_hex())
s = cm_df.style.background_gradient(cmap=my_cmap)
s
# Out:
# <style  type="text/css" >
#     #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col0 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col2 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col3 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col4 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col11 {
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row0_col13 {
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col1 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col2 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col3 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col4 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row1_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col2 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col3 {
#             background-color:  #37a266;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col4 {
#             background-color:  #aadfd3;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row2_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col2 {
#             background-color:  #5cbd98;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col3 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col4 {
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row3_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row4_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row4_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row4_col2 {
#             background-color:  #48b27f;
#             color:  #000000;
#         }    #T_643cb2e6_dd5c_11e9_9575_705a0f4b5639row4_col3 {
#             background-color:  #48b27f;
#             colo

# %%
test.head(5)

# %% [markdown]
# # Save Model

# %%
net_path = 'trained_net.pt'
torch.save(net, net_path)
# Out:
# /home/hal9002/.local/lib/python3.5/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # Test Run

# %%
### Load model
net_path = 'trained_net.pt'
net = torch.load(net_path)

net.eval()

input_names = ['Hello', 'aaaaaaaaaaaaaaa']
message_embedding = sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: input_names})

# Uncomment 2 lines below for sample:
input_names = all_data['Name'].iloc[0:4]
message_embedding = all_data['Name_emb'].iloc[0:4]

tensor_input = torch.Tensor(message_embedding).to(device)
tensor_input
predicted_class_score = [(int(torch.argmax(x)), max(x)) for x in net(tensor_input)]

print('{0:<40} {1:<20} {2:<10}'.format('Name', 'Class', 'Score'))
print()
for enum, x in enumerate(predicted_class_score):
    print('{0:<40} {1:<20} {2:<10.2f}'.format(input_names[enum], class_dict[x[0]], x[1]))
# Out:
# Name                                     Class                Score
#
# E. D. Abbott Ltd                         OfficeHolder         0.88
# Schwan-Stabilo                           Village              0.88
# Q-workshop                               Company              1.00
# Marvell Software Solutions Israel        Company              1.00

# %%
net(tensor_input)
# Out:
# tensor([[0.4245, 0.0451, 0.5307, 0.5348, 0.5632, 0.5189, 0.4170, 0.5000, 0.5190,
#          0.5436, 0.5073, 0.4648, 0.5000, 0.5759, 0.5162],
#         [0.5755, 0.9549, 0.4693, 0.4652, 0.4368, 0.4811, 0.5830, 0.5000, 0.4810,
#          0.4564, 0.4927, 0.5352, 0.5000, 0.4241, 0.4838]], device='cuda:0',
#        grad_fn=<SoftmaxBackward>)

# %%
tensor_input
# Out:
# tensor([[ 0.0056,  0.0254, -0.0183,  ..., -0.0174,  0.0042, -0.0457],
#         [-0.0786,  0.0270,  0.0564,  ...,  0.0337,  0.0276, -0.0603]],
#        device='cuda:0')

# %%
class_dict
# Out:
# {1: 'Company',
#  2: 'EducationalInstitution',
#  3: 'Artist',
#  4: 'Athlete',
#  5: 'OfficeHolder',
#  6: 'MeanOfTransportation',
#  7: 'Building',
#  8: 'NaturalPlace',
#  9: 'Village',
#  10: 'Animal',
#  11: 'Plant',
#  12: 'Album',
#  13: 'Film',
#  14: 'WrittenWork'}

# %%
all_data.iloc[0:4]
# Out:
#    Class                               Name  \
# 0      1                   E. D. Abbott Ltd
# 1      1                     Schwan-Stabilo
# 2      1                         Q-workshop
# 3      1  Marvell Software Solutions Israel
#
#                                             Name_emb Class_name
# 0  [-0.08377792, 0.009436725, 0.023043508, -0.025...    Company
# 1  [-0.029201776, -0.072018564, 0.015953422, -0.0...    Company
# 2  [-0.038690265, -0.016229104, -0.03456407, -0.0...    Company
# 3  [-0.0061697974, 0.039221164, -0.017827868, -0....    Company
