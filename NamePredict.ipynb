# %% [markdown]
# # Load Data

# %%
import pandas as pd

data_path = 'data/data.csv'
all_data = pd.read_csv(data_path, sep=',')
pd.set_option('max_rows', 30)

# %%
class_dict = {1:'Company',
              2:'EducationalInstitution',
              3:'Artist',
              4:'Athlete',
              5:'OfficeHolder',
              6:'MeanOfTransportation',
              7:'Building',
              8:'NaturalPlace',
              9:'Village',
              10:'Animal',
              11:'Plant',
              12:'Album',
              13:'Film',
              14:'WrittenWork'}

# %%
all_data['Class_name'] = all_data['Class'].map(class_dict)
all_data
# Out:
#         Class                                     Name   Class_name
# 0           1                         E. D. Abbott Ltd      Company
# 1           1                           Schwan-Stabilo      Company
# 2           1                               Q-workshop      Company
# 3           1        Marvell Software Solutions Israel      Company
# 4           1              Bergan Mercy Medical Center      Company
# 5           1                       The Unsigned Guide      Company
# 6           1                        Rest of the world      Company
# 7           1                               Globoforce      Company
# 8           1                                Rompetrol      Company
# 9           1                          Wave Accounting      Company
# 10          1                       Angstrem (company)      Company
# 11          1                          I-innovate (UK)      Company
# 12          1                                      JVC      Company
# 13          1                                 Toei Bus      Company
# 14          1                        Tear Drop Records      Company
# ...       ...                                      ...          ...
# 548772     14                             HaOlam HaZeh  WrittenWork
# 548773     14                         The OMAC Project  WrittenWork
# 548774     14                        Fledgling (novel)  WrittenWork
# 548775     14                      Death of a Salesman  WrittenWork
# 548776     14            The Wild Geese (Carney novel)  WrittenWork
# 548777     14                           Fluide Glacial  WrittenWork
# 548778     14                           Poison in Jest  WrittenWork
# 548779     14                      Out of This Furnace  WrittenWork
# 548780     14                             Bush's Brain  WrittenWork
# 548781     14                          Risk (magazine)  WrittenWork
# 548782     14           The Worst Band in the Universe  WrittenWork
# 548783     14                    Poor Arnold's Almanac  WrittenWork
# 548784     14  The Girls' Guide to Hunting and Fishing  WrittenWork
# 548785     14       Wash This Blood Clean from My Hand  WrittenWork
# 548786     14       Virginia Environmental Law Journal  WrittenWork
#
# [548787 rows x 3 columns]

# %% [markdown]
# # Remove Annotations (anything between parenthesis)

# %%
import re
all_data['Name'] = [re.sub(r'\([^)]*\)', '', x) for x in all_data['Name']]
all_data
# Out:
#         Class                                     Name   Class_name
# 0           1                         E. D. Abbott Ltd      Company
# 1           1                           Schwan-Stabilo      Company
# 2           1                               Q-workshop      Company
# 3           1        Marvell Software Solutions Israel      Company
# 4           1              Bergan Mercy Medical Center      Company
# 5           1                       The Unsigned Guide      Company
# 6           1                        Rest of the world      Company
# 7           1                               Globoforce      Company
# 8           1                                Rompetrol      Company
# 9           1                          Wave Accounting      Company
# 10          1                                Angstrem       Company
# 11          1                              I-innovate       Company
# 12          1                                      JVC      Company
# 13          1                                 Toei Bus      Company
# 14          1                        Tear Drop Records      Company
# ...       ...                                      ...          ...
# 548772     14                             HaOlam HaZeh  WrittenWork
# 548773     14                         The OMAC Project  WrittenWork
# 548774     14                               Fledgling   WrittenWork
# 548775     14                      Death of a Salesman  WrittenWork
# 548776     14                          The Wild Geese   WrittenWork
# 548777     14                           Fluide Glacial  WrittenWork
# 548778     14                           Poison in Jest  WrittenWork
# 548779     14                      Out of This Furnace  WrittenWork
# 548780     14                             Bush's Brain  WrittenWork
# 548781     14                                    Risk   WrittenWork
# 548782     14           The Worst Band in the Universe  WrittenWork
# 548783     14                    Poor Arnold's Almanac  WrittenWork
# 548784     14  The Girls' Guide to Hunting and Fishing  WrittenWork
# 548785     14       Wash This Blood Clean from My Hand  WrittenWork
# 548786     14       Virginia Environmental Law Journal  WrittenWork
#
# [548787 rows x 3 columns]

# %% [markdown]
# # Load USE

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import tf_sentencepiece

tf.logging.set_verbosity(tf.logging.ERROR)
module_url = 'module_Multi_Large/'

g = tf.Graph()
with g.as_default():
    similarity_input_placeholder = tf.placeholder(tf.string, shape=(None))
    embed = hub.Module(module_url)
    encoding_tensor = embed(similarity_input_placeholder)
    init_op = tf.group([tf.global_variables_initializer(), tf.tables_initializer()])
g.finalize()

sess = tf.Session(graph=g)
sess.run(init_op)

# %% [markdown]
# # Encode

# %%
from tqdm import tqdm

def embed_df(df, col):
    message_embedding = []
    size_batch = 200
    data_size = len(df[col])
    num_batches = int(data_size/size_batch)+1
    for x in tqdm(range(num_batches)):
        samples = list(df[col][(x*size_batch):((x+1)*size_batch)])
        if type(samples) is pd.core.series.Series:
            message_embedding.extend(sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: [samples]}))
        else:
            message_embedding.extend(sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: samples}))

    df[col+'_emb'] = message_embedding
    
    return df

# %%
import pickle

load = True
file_path = 'complete_data.pkl'

if load == True:
    with open(file_path, 'rb') as fl:
        all_data = pickle.load(fl)
else:
    columns = ['Name']
    for col in columns:
        all_data = embed_df(all_data, col)
    
    with open(file_path, 'wb') as fs:
        pickle.dump(all_data , fs)

# %% [markdown]
# # Check Data Distribution

# %%
all_data['Class'].value_counts().sort_values(ascending=False)
# Out:
# 1     40000
# 2     40000
# 3     40000
# 4     40000
# 5     40000
# 6     40000
# 7     40000
# 8     40000
# 9     40000
# 10    40000
# 11    40000
# 12    40000
# 13    40000
# 14    28787
# Name: Class, dtype: int64

# %% [markdown]
# # Split into Train, Validate and Test (Stratified)

# %%
from torch.utils.data import Dataset
import torch
import torch.utils.data as data

class my_dataset(Dataset):
    def __init__(self, data):
        input_ = [torch.tensor(x).float() for x in data['Name_emb'].values]
        label_ = [torch.tensor(x).long() for x in data['Class'].values]
        self.samples = list(zip(input_, label_))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# %%
from sklearn.model_selection import train_test_split

X = all_data.drop('Class', axis=1)
y = all_data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, stratify=y_test, test_size=0.5)

train = pd.concat([X_train, y_train.reindex(X_train.index)], axis=1)
validate = pd.concat([X_val, y_val.reindex(X_val.index)], axis=1)
test = pd.concat([X_test, y_test.reindex(X_test.index)], axis=1)

trainset = my_dataset(train)
validateset = my_dataset(validate)
testset = my_dataset(test)
print('Dataset Length: \n -train (90%%):\t\t %d \n -validate (10%%):\t %d \n -test (10%%):\t\t %d' % (len(trainset), len(validateset), len(testset)))
# Out:
# Dataset Length:
#  -train (90%):		 439029
#  -validate (10%):	 54879
#  -test (10%):		 54879

# %%
batch_size = 5000

trainloader = data.DataLoader(trainset, batch_size=batch_size, num_workers=0, shuffle=True)
validateloader = data.DataLoader(validateset, batch_size=batch_size, num_workers=0, shuffle=True)
testloader = data.DataLoader(testset, batch_size=batch_size, num_workers=0, shuffle=True)

# %% [markdown]
# # Define Network

# %%
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Net(nn.Module):
    def __init__(self, EMBED_DIM, CLASS_DIM):
        super(Net, self).__init__()
        self.number_neurons = 500
        self.fc1 = nn.Linear(EMBED_DIM, self.number_neurons)
        
        self.fc2 = nn.Sequential(nn.BatchNorm1d(self.number_neurons),
                                 nn.Linear(self.number_neurons, self.number_neurons),
                                 nn.Dropout(0.3, inplace=True),
                                 
                                 nn.BatchNorm1d(self.number_neurons),
                                 nn.Linear(self.number_neurons, self.number_neurons),
                                 nn.Dropout(0.3, inplace=True)
                                )
        
        self.fc3 = nn.Sequential(
                                 nn.BatchNorm1d(self.number_neurons),
                                 nn.Linear(self.number_neurons, CLASS_DIM)
                                )
        
    def forward(self, x):
        x = F.leaky_relu(self.fc1(x))
        x = F.leaky_relu(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return (x)
    
EMBED_DIM, CLASS_DIM = trainloader.dataset[0][0].shape[0], len(class_dict)+1

net = Net(EMBED_DIM, CLASS_DIM)
net.to(device)
# Out:
# Net(
#   (fc1): Linear(in_features=512, out_features=500, bias=True)
#   (fc2): Sequential(
#     (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Linear(in_features=500, out_features=500, bias=True)
#     (2): Dropout(p=0.3, inplace=True)
#     (3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Linear(in_features=500, out_features=500, bias=True)
#     (5): Dropout(p=0.3, inplace=True)
#   )
#   (fc3): Sequential(
#     (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Linear(in_features=500, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# # Define Evaluate Function

# %%
def evaluate(net, data_loader):

    loss = []
    accuracy = []

    y_true = []
    y_pred = []
    
    for input_labels in data_loader:
        inputs, labels = input_labels[0].to(device), input_labels[1].to(device)

        outputs = net(inputs)

        loss.append(criterion(outputs, labels).data.cpu().numpy())
        outputs = outputs.to('cpu').detach().numpy() 
        labels = labels.to('cpu').detach().numpy() 

        predict = [np.argmax(x) for x in outputs]
        labels = np.array([int(x) for x in labels])

        accuracy.append(list(predict==labels).count(True)/len(predict))

        y_true.extend(labels)
        y_pred.extend(predict)
        

    print('Acc: %.2f'% np.mean(accuracy))
    print('Loss: %.2f'% np.mean(loss))
    return y_true, y_pred

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.5, momentum=0.5)

# %%
display_n_loss = 3
display_n_loss = int(len(trainset)/(display_n_loss * batch_size))

EPOCHS = 100
display_n_epoch = 10

for epoch in range(EPOCHS):  # loop over the dataset multiple times

    running_loss = 0.0
    net.train()
    print('--------------- Epoch', epoch)
    for i, input_labels in enumerate(trainloader, 0):
        inputs, labels = input_labels[0].to(device), input_labels[1].to(device)
    
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        
        if i % display_n_loss == display_n_loss-1:    # print every N mini-batches
            print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, running_loss / display_n_loss))
            running_loss = 0.0
            
    if epoch % display_n_epoch == display_n_epoch-1:
        net.eval()

        print('-> Evaluate') 
        print('\tTrain:')
        evaluate(net, trainloader)
        print('\tValidate:')
        evaluate(net, validateloader)
        print('\tTest:')
        evaluate(net, testloader)

print('Finished Training')
# Out:
# --------------- Epoch 0
# [1,    29] loss: 2.376
# [1,    58] loss: 2.235
# [1,    87] loss: 2.220
# --------------- Epoch 1
# [2,    29] loss: 2.209
# [2,    58] loss: 2.205
# [2,    87] loss: 2.200
# --------------- Epoch 2
# [3,    29] loss: 2.194
# [3,    58] loss: 2.193
# [3,    87] loss: 2.186
# --------------- Epoch 3
# [4,    29] loss: 2.178
# [4,    58] loss: 2.178
# [4,    87] loss: 2.176
# --------------- Epoch 4
# [5,    29] loss: 2.171
# [5,    58] loss: 2.169
# [5,    87] loss: 2.172
# --------------- Epoch 5
# [6,    29] loss: 2.166
# [6,    58] loss: 2.164
# [6,    87] loss: 2.164
# --------------- Epoch 6
# [7,    29] loss: 2.159
# [7,    58] loss: 2.161
# [7,    87] loss: 2.162
# --------------- Epoch 7
# [8,    29] loss: 2.156
# [8,    58] loss: 2.157
# [8,    87] loss: 2.158
# --------------- Epoch 8
# [9,    29] loss: 2.151
# [9,    58] loss: 2.155
# [9,    87] loss: 2.157
# --------------- Epoch 9
# [10,    29] loss: 2.150
# [10,    58] loss: 2.152
# [10,    87] loss: 2.153
# -> Evaluate
# 	Train:
# Acc: 0.66
# Loss: 2.16
# 	Validate:
# Acc: 0.64
# Loss: 2.18
# 	Test:
# Acc: 0.64
# Loss: 2.18
# --------------- Epoch 10
# [11,    29] loss: 2.148
# [11,    58] loss: 2.148
# [11,    87] loss: 2.151
# --------------- Epoch 11
# [12,    29] loss: 2.145
# [12,    58] loss: 2.146
# [12,    87] loss: 2.147
# --------------- Epoch 12
# [13,    29] loss: 2.142
# [13,    58] loss: 2.143
# [13,    87] loss: 2.144
# --------------- Epoch 13
# [14,    29] loss: 2.139
# [14,    58] loss: 2.142
# [14,    87] loss: 2.143
# --------------- Epoch 14
# [15,    29] loss: 2.139
# [15,    58] loss: 2.139
# [15,    87] loss: 2.142
# --------------- Epoch 15
# [16,    29] loss: 2.135
# [16,    58] loss: 2.139
# [16,    87] loss: 2.137
# --------------- Epoch 16
# [17,    29] loss: 2.132
# [17,    58] loss: 2.137
# [17,    87] loss: 2.135
# --------------- Epoch 17
# [18,    29] loss: 2.129
# [18,    58] loss: 2.133
# [18,    87] loss: 2.136
# --------------- Epoch 18
# [19,    29] loss: 2.128
# [19,    58] loss: 2.130
# [19,    87] loss: 2.132
# --------------- Epoch 19
# [20,    29] loss: 2.128
# [20,    58] loss: 2.128
# [20,    87] loss: 2.128
# -> Evaluate
# 	Train:
# Acc: 0.69
# Loss: 2.13
# 	Validate:
# Acc: 0.65
# --------------- Epoch 88
# [89,    29] loss: 2.057
# [89,    58] loss: 2.058
# [89,    87] loss: 2.060
# --------------- Epoch 89
# [90,    29] loss: 2.055
# [90,    58] loss: 2.057
# [90,    87] loss: 2.059
# -> Evaluate
# 	Train:
# Acc: 0.76
# Loss: 2.06
# 	Validate:
# Acc: 0.66
# Loss: 2.15
# 	Test:
# Acc: 0.66
# Loss: 2.15
# --------------- Epoch 90
# [91,    29] loss: 2.055
# [91,    58] loss: 2.058
# [91,    87] loss: 2.057
# --------------- Epoch 91
# [92,    29] loss: 2.055
# [92,    58] loss: 2.056
# [92,    87] loss: 2.057
# --------------- Epoch 92
# [93,    29] loss: 2.055
# [93,    58] loss: 2.054
# [93,    87] loss: 2.058
# --------------- Epoch 93
# [94,    29] loss: 2.052
# [94,    58] loss: 2.056
# [94,    87] loss: 2.057
# --------------- Epoch 94
# [95,    29] loss: 2.052
# [95,    58] loss: 2.056
# [95,    87] loss: 2.056
# --------------- Epoch 95
# [96,    29] loss: 2.053
# [96,    58] loss: 2.055
# [96,    87] loss: 2.056
# --------------- Epoch 96
# [97,    29] loss: 2.052
# [97,    58] loss: 2.053
# [97,    87] loss: 2.055
# --------------- Epoch 97
# [98,    29] loss: 2.053
# [98,    58] loss: 2.053
# [98,    87] loss: 2.053
# --------------- Epoch 98
# [99,    29] loss: 2.053
# [99,    58] loss: 2.052
# [99,    87] loss: 2.054
# --------------- Epoch 99
# [100,    29] loss: 2.051
# [100,    58] loss: 2.052
# [100,    87] loss: 2.052
# -> Evaluate
# 	Train:
# Acc: 0.76
# Loss: 2.06
# 	Validate:
# Acc: 0.66
# Loss: 2.16
# 	Test:
# Acc: 0.66
# Loss: 2.15
# Finished Training

# %%
print('-> Evaluate') 
net.eval()
print('\tTrain:')
evaluate(net, trainloader)
print('\tValidate:')
evaluate(net, validateloader)
print('\tTest:')
evaluate(net, testloader)
print()
# Out:
# -> Evaluate
# 	Train:
# Acc: 0.76
# Loss: 2.06
# 	Validate:
# Acc: 0.66
# Loss: 2.16
# 	Test:
# Acc: 0.66
# Loss: 2.15

# %% [markdown]
# # Statistics on Test data

# %%
from pandas_ml import ConfusionMatrix

y_true, y_pred = evaluate(net, testloader)
cm = ConfusionMatrix(y_true, y_pred)
# Out:
# Acc: 0.66
# Loss: 2.15

# %%
pd.set_option('precision', 3)

cm_df_report = cm.classification_report
classes_name = list(class_dict.values())
classes_name.append('Avg_Total')

cm_df_report.index = classes_name
cm_df_report
# Out:
#                        precision recall F1_score support
# Company                    0.707  0.716    0.711    4000
# EducationalInstitution     0.947  0.953     0.95    4000
# Artist                     0.403  0.312    0.352    4000
# Athlete                    0.438  0.592    0.503    4000
# OfficeHolder               0.507  0.455     0.48    4000
# MeanOfTransportation       0.908  0.885    0.896    4000
# Building                   0.851  0.833    0.842    4000
# NaturalPlace                0.81  0.796    0.803    4000
# Village                    0.679  0.835    0.749    4000
# Animal                      0.69  0.659    0.674    4000
# Plant                      0.683  0.789    0.732    4000
# Album                      0.541  0.595    0.567    4000
# Film                       0.501  0.405    0.448    4000
# WrittenWork                0.549  0.376    0.446    2879
# Avg_Total                   0.66  0.663    0.658   54879

# %%
cm_od = cm.stats()
cm_od['class'].columns = class_dict.values()
cm_od['class']
# Out:
# /home/hal9002/.local/lib/python3.5/site-packages/pandas_ml/confusion_matrix/stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
#                                       Company EducationalInstitution  Artist  \
# Population                              54879                  54879   54879
# P: Condition positive                    4000                   4000    4000
# N: Condition negative                   50879                  50879   50879
# Test outcome positive                    4046                   4022    3098
# Test outcome negative                   50833                  50857   51781
# TP: True Positive                        2862                   3810    1248
# TN: True Negative                       49695                  50667   49029
# FP: False Positive                       1184                    212    1850
# FN: False Negative                       1138                    190    2752
# TPR: (Sensitivity, hit rate, recall)    0.716                  0.953   0.312
# TNR=SPC: (Specificity)                  0.977                  0.996   0.964
# PPV: Pos Pred Value (Precision)         0.707                  0.947   0.403
# NPV: Neg Pred Value                     0.978                  0.996   0.947
# FPR: False-out                         0.0233                0.00417  0.0364
# FDR: False Discovery Rate               0.293                 0.0527   0.597
# FNR: Miss Rate                          0.284                 0.0475   0.688
# ACC: Accuracy                           0.958                  0.993   0.916
# F1 score                                0.711                   0.95   0.352
# MCC: Matthews correlation coefficient   0.689                  0.946    0.31
# Informedness                            0.692                  0.948   0.276
# Markedness                              0.685                  0.944    0.35
# Prevalence                             0.0729                 0.0729  0.0729
# LR+: Positive likelihood ratio           30.7                    229    8.58
# LR-: Negative likelihood ratio          0.291                 0.0477   0.714
# DOR: Diagnostic odds ratio                106               4.79e+03      12
# FOR: False omission rate               0.0224                0.00374  0.0531
#
#                                       Athlete OfficeHolder  \
# Population                              54879        54879
# P: Condition positive                    4000         4000
# N: Condition negative                   50879        50879
# Test outcome positive                    5413         3590
# Test outcome negative                   49466        51289
# TP: True Positive                        2369         1821
# TN: True Negative                       47835        49110
# FP: False Positive                       3044         1769
# FN: False Negative                       1631         2179
# TPR: (Sensitivity, hit rate, recall)    0.592        0.455
# TNR=SPC: (Specificity)                   0.94        0.965
# PPV: Pos Pred Value (Precision)         0.438        0.507
# NPV: Neg Pred Value                     0.967        0.958
# FPR: False-out                         0.0598       0.0348
# FDR: False Discovery Rate               0.562        0.493
# FNR: Miss Rate                          0.408        0.545
# ACC: Accuracy                           0.915        0.928
# F1 score                                0.503         0.48
# MCC: Matthews correlation coefficient   0.464        0.442
# Informedness                            0.532         0.42
# Markedness                              0.405        0.465
# Prevalence                             0.0729       0.0729
# LR+: Positive likelihood ratio            9.9         13.1
# LR-: Negative likelihood ratio          0.434        0.564
# DOR: Diagnostic odds ratio               22.8         23.2
# FOR: False omission rate                0.033       0.0425
#
#                                       MeanOfTransportation Building  \
# Population                                           54879    54879
# P: Condition positive                                 4000     4000
# N: Condition negative                                50879    50879
# Test outcome positive                                 3901     3912
# Test outcome negative                                50978    50967
# TP: True Positive                                     3541     3331
# TN: True Negative                                    50519    50298
# FP: False Positive                                     360      581
# FN: False Negative                                     459      669
# TPR: (Sensitivity, hit rate, recall)                 0.885    0.833
# TNR=SPC: (Specificity)                               0.993    0.989
# PPV: Pos Pred Value (Precision)                      0.908    0.851
# NPV: Neg Pred Value                                  0.991    0.987
# FPR: False-out                                     0.00708   0.0114
# FDR: False Discovery Rate                           0.0923    0.149
# FNR: Miss Rate                                       0.115    0.167
# ACC: Accuracy                                        0.985    0.977
# F1 score                                             0.896    0.842
# MCC: Matthews correlation coefficient                0.888     0.83
# Informedness                                         0.878    0.821
# Markedness                                           0.899    0.838
# Prevalence                                          0.0729   0.0729
# LR+: Positive likelihood ratio                         125     72.9
# LR-: Negative likelihood ratio                       0.116    0.169
# DOR: Diagnostic odds ratio                        1.08e+03      431
# FOR: False omission rate                             0.009   0.0131
#
#                                       NaturalPlace Village  Animal   Plant  \
# Population                                   54879   54879   54879   54879
# P: Condition positive                         4000    4000    4000    4000
# N: Condition negative                        50879   50879   50879   50879
# Test outcome positive                         3933    4918    3820    4620
# Test outcome negative                        50946   49961   51059   50259
# TP: True Positive                             3186    3338    2636    3157
# TN: True Negative                            50132   49299   49695   49416
# FP: False Positive                             747    1580    1184    1463
# FN: False Negative                             814     662    1364     843
# TPR: (Sensitivity, hit rate, recall)         0.796   0.835   0.659   0.789
# TNR=SPC: (Specificity)                       0.985   0.969   0.977   0.971
# PPV: Pos Pred Value (Precision)               0.81   0.679    0.69   0.683
# NPV: Neg Pred Value                          0.984   0.987   0.973   0.983
# FPR: False-out                              0.0147  0.0311  0.0233  0.0288
# FDR: False Discovery Rate                     0.19   0.321    0.31   0.317
# FNR: Miss Rate                               0.203   0.166   0.341   0.211
# ACC: Accuracy                                0.972   0.959   0.954   0.958
# F1 score                                     0.803   0.749   0.674   0.732
# MCC: Matthews correlation coefficient        0.788   0.731   0.649   0.712
# Informedness                                 0.782   0.803   0.636    0.76
# Markedness                                   0.794   0.665   0.663   0.667
# Prevalence                                  0.0729  0.0729  0.0729  0.0729
# LR+: Positive likelihood ratio                54.3    26.9    28.3    27.4
# LR-: Negative likelihood ratio               0.207   0.171   0.349   0.217
# DOR: Diagnostic odds ratio                     263     157    81.1     126
# FOR: False omission rate                     0.016  0.0133  0.0267  0.0168
#
#                                         Album    Film WrittenWork
# Population                              54879   54879       54879
# P: Condition positive                    4000    4000        2879
# N: Condition negative                   50879   50879       52000
# Test outcome positive                    4398    3236        1972
# Test outcome negative                   50481   51643       52907
# TP: True Positive                        2381    1620        1082
# TN: True Negative                       48862   49263       51110
# FP: False Positive                       2017    1616         890
# FN: False Negative                       1619    2380        1797
# TPR: (Sensitivity, hit rate, recall)    0.595   0.405       0.376
# TNR=SPC: (Specificity)                   0.96   0.968       0.983
# PPV: Pos Pred Value (Precision)         0.541   0.501       0.549
# NPV: Neg Pred Value                     0.968   0.954       0.966
# FPR: False-out                         0.0396  0.0318      0.0171
# FDR: False Discovery Rate               0.459   0.499       0.451
# FNR: Miss Rate                          0.405   0.595       0.624
# ACC: Accuracy                           0.934   0.927       0.951
# F1 score                                0.567   0.448       0.446
# MCC: Matthews correlation coefficient   0.532   0.412        0.43
# Informedness                            0.556   0.373       0.359
# Markedness                              0.509   0.455       0.515
# Prevalence                             0.0729  0.0729      0.0525
# LR+: Positive likelihood ratio             15    12.8          22
# LR-: Negative likelihood ratio          0.421   0.615       0.635
# DOR: Diagnostic odds ratio               35.6    20.7        34.6
# FOR: False omission rate               0.0321  0.0461       0.034

# %% [markdown]
# # Confusion Matrix

# %%
cm_df = cm.to_dataframe()
cm_df.columns = class_dict.values()
cm_df.index = class_dict.values()

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap

my_cmap = ListedColormap(sns.color_palette("BuGn", 14).as_hex())
s = cm_df.style.background_gradient(cmap=my_cmap)
s
# Out:
# <style  type="text/css" >
#     #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col0 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col2 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col3 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col4 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col11 {
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row0_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col1 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col2 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col3 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col4 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row1_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col2 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col3 {
#             background-color:  #48b27f;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col4 {
#             background-color:  #74c8ae;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row2_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col2 {
#             background-color:  #48b27f;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col3 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col4 {
#             background-color:  #aadfd3;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col5 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col6 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col7 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col8 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col9 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col10 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col11 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col12 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row3_col13 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row4_col0 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row4_col1 {
#             background-color:  #edf8fb;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row4_col2 {
#             background-color:  #5cbd98;
#             color:  #000000;
#         }    #T_d686cfce_dd72_11e9_9575_705a0f4b5639row4_col3 {
#             background-color:  #5cbd98;
#             colo

# %% [markdown]
# # Save Model

# %%
net_path = 'trained_net.pt'
torch.save(net, net_path)
# Out:
# /home/hal9002/.local/lib/python3.5/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # Test Run

# %%
### Load model
net_path = 'trained_net.pt'
net = torch.load(net_path)

net.eval()

input_names = ['Hello', 'aaaaaaaaaaaaaaa', 'Streetbee']
message_embedding = sess.run(encoding_tensor, feed_dict={similarity_input_placeholder: input_names})

# Uncomment 2 lines below for sample:
# input_names = all_data['Name'].iloc[0:10]
# message_embedding = all_data['Name_emb'].iloc[0:10]

tensor_input = torch.Tensor(message_embedding).to(device)
tensor_input
predicted_class_score = [(int(torch.argmax(x)), max(x)) for x in net(tensor_input)]

print('{0:<40} {1:<20} {2:<10}'.format('Name', 'Class', 'Score'))
print()
for enum, x in enumerate(predicted_class_score):
    print('{0:<40} {1:<20} {2:<10.2f}'.format(input_names[enum], class_dict[x[0]], x[1]))
# Out:
# Name                                     Class                Score
#
# Hello                                    Album                1.00
# aaaaaaaaaaaaaaa                          Album                1.00
# Streetbee                                Company              1.00
